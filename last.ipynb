# %% [markdown]
# <a href="https://colab.research.google.com/github/Arik096/big_data_analysis/blob/main/last.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('/content/drive/MyDrive/arik/country_wise_latest.csv')

# %%
print('country wise data shape ', df.shape)
df.head(5)
# Out:
# country wise data shape  (187, 15)
#   Country/Region  Confirmed  ...  1 week % increase             WHO Region
# 0    Afghanistan      36263  ...               2.07  Eastern Mediterranean
# 1        Albania       4880  ...              17.00                 Europe
# 2        Algeria      27973  ...              18.07                 Africa
# 3        Andorra        907  ...               2.60                 Europe
# 4         Angola        950  ...              26.84                 Africa
#
# [5 rows x 15 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country/Region          187 non-null    object
#  1   Confirmed               187 non-null    int64
#  2   Deaths                  187 non-null    int64
#  3   Recovered               187 non-null    int64
#  4   Active                  187 non-null    int64
#  5   New cases               187 non-null    int64
#  6   New deaths              187 non-null    int64
#  7   New recovered           187 non-null    int64
#  8   Deaths / 100 Cases      187 non-null    float64
#  9   Recovered / 100 Cases   187 non-null    float64
#  10  Deaths / 100 Recovered  187 non-null    float64
#  11  Confirmed last week     187 non-null    int64
#  12  1 week change           187 non-null    int64
#  13  1 week % increase       187 non-null    float64
# ...

# %%
df.describe()
# Out:
#           Confirmed         Deaths  ...  1 week change  1 week % increase
# count  1.870000e+02     187.000000  ...     187.000000         187.000000
# mean   8.813094e+04    3497.518717  ...    9448.459893          13.606203
# std    3.833187e+05   14100.002482  ...   47491.127684          24.509838
# min    1.000000e+01       0.000000  ...     -47.000000          -3.840000
# 25%    1.114000e+03      18.500000  ...      49.000000           2.775000
# 50%    5.059000e+03     108.000000  ...     432.000000           6.890000
# 75%    4.046050e+04     734.000000  ...    3172.000000          16.855000
# max    4.290259e+06  148011.000000  ...  455582.000000         226.320000
#
# [8 rows x 13 columns]

# %%
# !pip install chart_studio
# Out:
# ...
#      |████████████████████████████████| 64 kB 2.3 MB/s
# ...

# %%
import pandas as pd
import numpy as np
import chart_studio.plotly as py
import cufflinks as cf
import seaborn as sns
import plotly.express as px
# %matplotlib inline

# %%
import plotly.graph_objects as go


# Display death due to covid data for various countries 
fig = px.bar(df[151:188], y='New cases', x='Country/Region', text='New cases', color='Country/Region')
# Put bar total value above bars with 2 values of precision
fig.update_traces(texttemplate='%{text:.2s}', textposition='outside')
fig.update_layout(xaxis_tickangle=-45)
fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="bbe23602-9f9a-44fd-b99f-6bb6f2fa5337" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("bbe23602-9f9a-44fd-b99f-6bb6f2fa5337")) {
#                     Plotly.newPlot(
#                         'bbe23602-9f9a-44fd-b99f-6bb6f2fa5337',
# ...

# %%
# pie chart for illustration of new cases of South-east Asia

#new_cases_asia = df[df['WHO Region'] == 'Americas']


px.pie(df, values='Confirmed last week', names='WHO Region', 
       title='Confirmed last week in different region', 
       color_discrete_sequence=px.colors.sequential.RdBu)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="76148dce-92fe-4121-a7ab-3d5c9a5600c8" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("76148dce-92fe-4121-a7ab-3d5c9a5600c8")) {
#                     Plotly.newPlot(
#                         '76148dce-92fe-4121-a7ab-3d5c9a5600c8',
# ...
